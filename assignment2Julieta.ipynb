# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import constants

plt.rcParams.update({"font.size":16, "axes.labelsize":16, "font.family":"sans-serif", 
                     "font.sans-serif":"Arial"})

# %% [markdown]
# Recall that in PHYS 207, you were often asked to plot displacement as a function of time. For example, for a baseball thrown directly upward you would plot $y(t)$, and for a block on a horizontal spring you would plot $x(t)$. Here we will examine how the displacement and time axes "scissor together" at relativistic speeds.
#
# Imagine that frame $K^{\prime}$ is moving in the $+x$ direction at speed $v$ relative to frame $K$. You are at rest in frame $K$. Let's figure out how the set of $(t^{\prime},x^{\prime})$ axes would look to you when the frames' origins $O$ and $O^{\prime}$ coincide.
#
# <ol>
#     <li>Use the fact that $x^{\prime} = 0$ on the $t^{\prime}$ axis to define a line $x(t)$ in frame $K$ that follows the $t^{\prime}$ axis. Write a function that computes points on the line. $v$ will be one of your function inputs.</li>
# </ol>

# %%
# Constant 
c = 3e8 #m/s

#Function to compute points on the line of the t'axis
#Lorentz transformation makes x=gamma*(x'+(v*t')), but since x'=0 on the t' axis, Lorentz transformation equation
#simplifies to x=gamma*v*t'
def xoft(v,tprime):
    gamma = np.sqrt(1/(1-((v**2)/(c**2))))
    x1=gamma*v*tprime
    return x1

# %% [markdown]
# <ol start=2>
#     <li>Use the fact that $t^{\prime} = 0$ on the $x^{\prime}$ axis to define a line $x(t)$ that traces the $x^{\prime}$ axis in frame $K$. Write a second function that computes points on this line.</li>
# </ol>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import constants

plt.rcParams.update({"font.size":16, "axes.labelsize":16, "font.family":"sans-serif", 
                     "font.sans-serif":"Arial"})

# Constant 
c = 3e8 #m/s

#Function to compute points on the line of the x'axis
#Lorentz transformation makes x=gamma*(x'+(v*t')), but since t'=0 on the x' axis, Lorentz transformation equation
#simplifies to x=gamma*x'
def xoft2(v,xprime):
    gamma = np.sqrt(1/(1-((v**2)/(c**2))))
    x2=gamma*xprime
    return x2

# %% [markdown]
# <ol start=3>
#     <li>The code below creates a figure with centered $(ct,x)$ axes that have range $(-10^{10}, 10^{10})$. We are using $ct$ instead of just $t$ on our horizontal axis so that both axes have the same units. Use your functions from problems 1 and 2 to overplot the $t^{\prime}$ and $x^{\prime}$ axes <strong>as a function of $ct$</strong> for $v = 0.2c$. Make your $t^{\prime}$ and $x^{\prime}$ axes red, and label them in red.</li>
# </ol>

# %%
def xoft(v,ct):
    gamma = np.sqrt(1/(1-((v**2)/(c**2))))
    x1=gamma*v*t
    return x1

def xoft2(v,xprime):
    gamma = np.sqrt(1/(1-((v**2)/(c**2))))
    x2=gamma*xprime
    return x2


# Constant 
c = 3e8 #m/s
v = 0.2*c #m/s

# Set up an array of independent variables t that spans -100 to 100 seconds
t = np.linspace(0, 200, num=201, endpoint=True) - 100
#for both axis to have the same dimensions
ct = c*t
xprime=ct

# Make a figure
fig, ax = plt.subplots(figsize=(7,7))

# YOUR CODE HERE: Use ax.plot() to plot the t' and x' axes below
x_prime_t_axis = xoft(v,ct)
x_prime_x_axis = xoft2(v,xprime)

ax.plot(ct,x_prime_t_axis,label="t'axis",color="red")
ax.plot(ct,x_prime_x_axis,label="x'axis",color="darkred")

#Plot of the values for x in the t' axis
ax.scatter(0,0,color="red") #point of origin


# Move the left and bottom "spines" (borders of the plot) to the center
# This makes a math textbook-like set of (x,t) axes instead of a box around the plot
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))

# Take out the top and right spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Make the two axes have the same scale
ax.set_aspect('equal')

# Set the axes ranges
ax.set_xlim([-1e10, 1e10])
ax.set_ylim([-1e10, 1e10])

#Show legend
ax.legend()

#Show the plot
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# <ol start=4>
#     <li>Make a figure that plots $t^{\prime}$ and $x^{\prime}$ axes for $v = 0.25c$, $v = 0.5c$, and $v = 0.75c$. Use different colors for each pair of axes. Make a legend that shows which value of $v$ corresponds to each color.</li>
# </ol>

# %%
# Plot here. You may copy syntax from the previous cell.
import numpy as np
import matplotlib.pyplot as plt
from scipy import constants

plt.rcParams.update({"font.size":16, "axes.labelsize":16, "font.family":"sans-serif", 
                     "font.sans-serif":"Arial"})

def xoft(v,ct):
    gamma = np.sqrt(1/(1-((v**2)/(c**2))))
    x1=gamma*v*t
    return x1

def xoft2(v,xprime):
    gamma = np.sqrt(1/(1-((v**2)/(c**2))))
    x2=gamma*xprime
    return x2


# Constant 
c = 3e8 #m/s
v1 = 0.25*c #m/s
v2 = 0.5*c #m/s
v3 = 0.75*c #m/s

# Set up an array of independent variables t that spans -100 to 100 seconds
t = np.linspace(0, 200, num=201, endpoint=True) - 100
#for both axis to have the same dimensions
ct = c*t
xprime=ct

# Make a figure
fig, ax = plt.subplots(figsize=(7,7))

# YOUR CODE HERE: Use ax.plot() to plot the t' and x' axes below
x_prime_t_axis = xoft(v1,ct)
x_prime_x_axis = xoft2(v1,xprime)

ax.plot(ct,x_prime_t_axis,label="t'axis for v1",color="red")
ax.plot(ct,x_prime_x_axis,label="x'axis for v1",color="darkred")

x_prime_t_axis2 = xoft(v2,ct)
x_prime_x_axis2 = xoft2(v2,xprime)

ax.plot(ct,x_prime_t_axis2,label="t'axis for v2",color="lightblue")
ax.plot(ct,x_prime_x_axis2,label="x'axis for v2",color="blue")

x_prime_t_axis = xoft(v3,ct)
x_prime_x_axis = xoft2(v3,xprime)

ax.plot(ct,x_prime_t_axis,label="t'axis for v3",color="lightgreen")
ax.plot(ct,x_prime_x_axis,label="x'axis for v3",color="green")


# Move the left and bottom "spines" (borders of the plot) to the center
# This makes a math textbook-like set of (x,t) axes instead of a box around the plot
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))

# Take out the top and right spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Make the two axes have the same scale
ax.set_aspect('equal')

# Set the axes ranges
ax.set_xlim([-1e10, 1e10])
ax.set_ylim([-1e10, 1e10])

#Show legend
ax.legend()

#Show the plot
plt.show()

# %% [markdown]
# <ol start=5>
#     <li>Connect your graph from problem 4 with the discussion of world lines in Chapter 2 of your textbook. What kind of world line do your $(t^{\prime}, x^{\prime})$ axes approach as $v \rightarrow c$? Create a similar plot to problem 4, but this time plot $(t^{\prime}, x^{\prime})$ axes for $v = 0.5, 0.75, 0.875, 0.9375$. To illustrate the concept of taking a limit as $v \rightarrow c$, make each set of $(t^{\prime}, x^{\prime})$ axes a successively darker shade of gray. Plot the limiting world line in black. Add a legend to show which value of $v$ corresponds to which shade of gray. You may find it helpful to specify line colors like this: <tt>color='0.7'</tt>.</li>
# </ol>

# %%
# Plot here
import numpy as np
import matplotlib.pyplot as plt
from scipy import constants

plt.rcParams.update({"font.size":16, "axes.labelsize":16, "font.family":"sans-serif", 
                     "font.sans-serif":"Arial"})

def xoft(v,ct):
    gamma = np.sqrt(1/(1-((v**2)/(c**2))))
    x1=gamma*v*t
    return x1

def xoft2(v,xprime):
    gamma = np.sqrt(1/(1-((v**2)/(c**2))))
    x2=gamma*xprime
    return x2


# Constant 
c = 3e8 #m/s
v1 = 0.5*c #m/s
v2 = 0.75*c #m/s
v3 = 0.875*c #m/s
v4 = 0.9375*c #m/s
vworldline = 0.99999999*c #m/s It doesn't let me plot it for velocity=c so I did a very very close value to c

# Set up an array of independent variables t that spans -100 to 100 seconds
t = np.linspace(0, 200, num=201, endpoint=True) - 100
#for both axis to have the same dimensions
ct = c*t
xprime=ct

# Make a figure
fig, ax = plt.subplots(figsize=(7,7))

# YOUR CODE HERE: Use ax.plot() to plot the t' and x' axes below
x_prime_t_axis = xoft(v1,ct)
x_prime_x_axis = xoft2(v1,xprime)

ax.plot(ct,x_prime_t_axis,label="t'axis for v1",color='0.2')
ax.plot(ct,x_prime_x_axis,label="x'axis for v1",color='0.2')

x_prime_t_axis2 = xoft(v2,ct)
x_prime_x_axis2 = xoft2(v2,xprime)

ax.plot(ct,x_prime_t_axis2,label="t'axis for v2",color='0.4')
ax.plot(ct,x_prime_x_axis2,label="x'axis for v2",color='0.4')

x_prime_t_axis = xoft(v3,ct)
x_prime_x_axis = xoft2(v3,xprime)

ax.plot(ct,x_prime_t_axis,label="t'axis for v3",color='0.6')
ax.plot(ct,x_prime_x_axis,label="x'axis for v3",color='0.6')

x_prime_t_axis = xoft(v4,ct)
x_prime_x_axis = xoft2(v4,xprime)

ax.plot(ct,x_prime_t_axis,label="t'axis for v4",color='0.8')
ax.plot(ct,x_prime_x_axis,label="x'axis for v4",color='0.8')

x_prime_t_axis = xoft(vworldline,ct)
x_prime_x_axis = xoft2(vworldline,xprime)

ax.plot(ct,x_prime_t_axis,label="t'axis for v=c",color='0')
ax.plot(ct,x_prime_x_axis,label="x'axis for v=c",color='0')




# Move the left and bottom "spines" (borders of the plot) to the center
# This makes a math textbook-like set of (x,t) axes instead of a box around the plot
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))

# Take out the top and right spines
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

# Make the two axes have the same scale
ax.set_aspect('equal')

# Set the axes ranges
ax.set_xlim([-1e10, 1e10])
ax.set_ylim([-1e10, 1e10])

#Show legend
ax.legend()

#Show the plot
plt.show()
